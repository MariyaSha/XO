# %%
import numpy as np
import pandas as pd
import math
from IPython.display import Markdown, display

# %%
#Setup Game Board
columns = ['A', 'B', 'C']
index = [1, 2, 3]

boxes = []

for i in index:
    for c in columns:
        boxes.append(c+str(i))

#storing a flat array of the original box values before transforming it
flat_boxes = boxes

boxes = np.array(boxes)
boxes = np.resize(boxes, (3,3))

#Initializing the game board dataframe
board = pd.DataFrame(boxes, index=index, columns=columns)

# %%
#Game Functions
def check_valid(move, game_over):
    '''ensuring user input values exist on the gameboard'''
    if move.upper() in flat_boxes and move.upper() in board.values:
        separator()
        print('Updating Game Board...')   
        separator()
    elif move.upper() in flat_boxes and move.upper() not in board.values:
        print('Oops! box is already taken')
        move = input('Please select a different box number\n')
        if move.upper() not in board.values:
            separator()
            print('Invalid Move... Exiting')
            separator()
            move = False
    elif move == "exit":
        game_over == True
    else:
        separator()
        print('Invalid entry!')
        separator()
        move = input('Please select a valid box number\n')
        if move.upper() not in board.values:
            separator()
            print('Invalid Move... Exiting')
            separator()
            move = False
    return move, game_over

def update_board(move):
    '''Updating the game board with the current player move'''
    board.values[board.values == move.upper()] = p.upper()
    display(style(board))
    return move

def horizontal(game_over):
    '''checking for a horizontal win scenario'''
    for row in board.values:
        if row[0] == row[1] == row[2]:
            game_over = True
            break
    return game_over

def vertical(game_over):
    '''checking for a vertical win scenario'''
    for column in ['A', 'B', 'C']:
        if board[column].values[0] == board[column].values[1] == board[column].values[2]:
            game_over = True
            break
    return game_over

def diagonal(game_over):
    '''checking for a diagonal win scenario'''
    diag = [
        board['A'].values[0] == board['B'].values[1] == board['C'].values[2],
        board['C'].values[0] == board['B'].values[1] == board['A'].values[2]
            ]
    for d in diag:
        if d:
            game_over = True
            break            
    return game_over

def separator():
    print('-------------------------------------------------------')

# %%
#Game Board styling functions
def background_X(move):
    '''setting up red backround for player X'''
    is_X = move == 'X'
    return ['background-color: red' if v else '' for v in is_X]

def background_O(move):
    '''setting up blue backround for player O'''
    is_O = move == 'O'
    return ['background-color: blue' if v else '' for v in is_O]

def style(df):
    '''setting up game board colours'''
    style = df.style.set_properties(**{'background-color': 'black',
                                                'color': 'white',
                                                'border-color': 'black'})
 
    style = style.apply(background_X)
    style = style.apply(background_O)
    return style

# %%
#Initial Parameters
players = ['X', 'O']
game_over = False
move_num = 1

#Displaying initial game board
display(style(board))

#Starting the game
while move_num < 10 and game_over == False:
    for p in players:
        separator()
        move = input('Player ' + p +'\nSelect your square! for example: B2\n')
        move, game_over = check_valid(move, game_over)
        if game_over == True or move == False or move == 'exit':
            print('\033[1m' + 'Game Over - Player {} Gave up'.format(p))
            move_num = 10
            break
        if move != False:
            move = update_board(move)
            game_over = horizontal(game_over)
            game_over = vertical(game_over)
            game_over = diagonal(game_over)
            if game_over == True:
                separator()
                print('\033[1m' + 'Player ' + p + ' Wins - GAME OVER!')
                move_num = 10
                break
            elif game_over == False and move_num >= 9:
                separator()
                print('\033[1m' + 'Nobody Wins! - GAME OVER')
        else:
            move_num = 10
            break
        move_num += 1
# Out:
# <style  type="text/css" >
#     #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col0 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col1 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col2 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col0 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col1 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col2 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col0 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col1 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }    #T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col2 {
#             background-color:  black;
#             color:  white;
#             border-color:  black;
#             : ;
#             : ;
#         }</style><table id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col0" class="data row0 col0" >A1</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col1" class="data row0 col1" >B1</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row0_col2" class="data row0 col2" >C1</td>
#             </tr>
#             <tr>
#                         <th id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col0" class="data row1 col0" >A2</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col1" class="data row1 col1" >B2</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row1_col2" class="data row1 col2" >C2</td>
#             </tr>
#             <tr>
#                         <th id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col0" class="data row2 col0" >A3</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col1" class="data row2 col1" >B3</td>
#                         <td id="T_bc8c8952_33eb_11ea_90f1_7845c4c8dd63row2_col2" class="data row2 col2" >C3</td>
#             </tr>
#     </tbody></table>
# -------------------------------------------------------
